# %% [markdown]
# # Java Kernel Test Notebook
#
# This notebook demonstrates the Java kernel wrapper for Jupyter.

# %% [markdown]
# ## Test 1: Simple Print Statement

# %%
System.out.println("Hello from Java in Jupyter!");

# %% [markdown]
# ## Test 2: Variables and Loops

# %%
int sum = 0;
for (int i = 1; i <= 10; i++) {
    sum += i;
}
System.out.println("Sum of 1 to 10: " + sum);

# %% [markdown]
# ## Test 3: Complete Class with Main Method

# %%
public class HelloWorld {
    public static void main(String[] args) {
        System.out.println("Hello, World!");
        
        // Demonstrate loops
        for (int i = 0; i < 5; i++) {
            System.out.println("Count: " + i);
        }
    }
}

# %% [markdown]
# ## Test 4: Using Java Collections

# %%
import java.util.*;

public class CollectionsDemo {
    public static void main(String[] args) {
        // ArrayList example
        List<String> fruits = new ArrayList<>();
        fruits.add("Apple");
        fruits.add("Banana");
        fruits.add("Cherry");
        
        System.out.println("Fruits:");
        for (String fruit : fruits) {
            System.out.println("- " + fruit);
        }
        
        // HashMap example
        Map<String, Integer> scores = new HashMap<>();
        scores.put("Alice", 95);
        scores.put("Bob", 87);
        scores.put("Charlie", 92);
        
        System.out.println("\nScores:");
        for (Map.Entry<String, Integer> entry : scores.entrySet()) {
            System.out.println(entry.getKey() + ": " + entry.getValue());
        }
    }
}

# %% [markdown]
# ## Test 5: Math Operations

# %%
public class MathDemo {
    public static void main(String[] args) {
        double radius = 5.0;
        double area = Math.PI * radius * radius;
        double circumference = 2 * Math.PI * radius;
        
        System.out.println("Circle with radius " + radius);
        System.out.printf("Area: %.2f%n", area);
        System.out.printf("Circumference: %.2f%n", circumference);
        
        // Random numbers
        System.out.println("\nRandom numbers:");
        Random random = new Random();
        for (int i = 0; i < 5; i++) {
            System.out.println("Random #" + (i+1) + ": " + random.nextInt(100));
        }
    }
}

# %% [markdown]
# ## Test 6: String Operations

# %%
String message = "Java in Jupyter is awesome!";
System.out.println("Original: " + message);
System.out.println("Uppercase: " + message.toUpperCase());
System.out.println("Length: " + message.length());
System.out.println("Contains 'Jupyter': " + message.contains("Jupyter"));

// String split
String[] words = message.split(" ");
System.out.println("\nWords:");
for (String word : words) {
    System.out.println("- " + word);
}

# %% [markdown]
# ## Test 7: Error Handling (This should show a compilation error)

# %%
// This cell should produce a compilation error
// Uncomment the line below to test error handling:
// int x = "this will cause an error";
